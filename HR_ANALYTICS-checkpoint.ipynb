# %% [markdown]
# # Import needed modules and get the required dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
# get the dataset
hr_dat = pd.read_csv('Downloads/ibm-hr-analytics-employee-attrition-performance/WA_Fn-UseC_-HR-Employee-Attrition.csv')
hr_dat.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %% [markdown]
# # EDA

# %%
#get info
hr_dat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %% [markdown]
# There are no missing values in the data.

# %%
#check total number of unique values in all columns
hr_dat.nunique()
# Out:
# Age                           43
# Attrition                      2
# BusinessTravel                 3
# DailyRate                    886
# Department                     3
# DistanceFromHome              29
# Education                      5
# EducationField                 6
# EmployeeCount                  1
# EmployeeNumber              1470
# EnvironmentSatisfaction        4
# Gender                         2
# HourlyRate                    71
# JobInvolvement                 4
# JobLevel                       5
# JobRole                        9
# JobSatisfaction                4
# MaritalStatus                  3
# MonthlyIncome               1349
# MonthlyRate                 1427
# NumCompaniesWorked            10
# Over18                         1
# OverTime                       2
# PercentSalaryHike             15
# PerformanceRating              2
# RelationshipSatisfaction       4
# StandardHours                  1
# StockOptionLevel               4
# ...

# %% [markdown]
# Here we can see some columns which have only 1 unique variable, that means all the values inside such columns are constant.We should drop such columns.
#
# The column employeenumber also shows redundancy.We should drop it too.
#
# Our target variable(Attrition) has 2 variables, means it is a classification problem.

# %%
#drop redundant columns
hr_dat.drop(['EmployeeCount','EmployeeNumber','Over18','StandardHours'],axis=1,inplace=True)

# %%
#plotting attrition column
plt.figure(figsize=(20,5))
sns.countplot(hr_dat['Attrition'])
plt.show()

# %% [markdown]
# This column is biased,there are way more 'No's than 'Yes's.
#
# After seeing above plot, we can say that, it is more likely for an employee to stay than to leave a firm.

# %%
#plotting age v/s attrition
plt.figure(figsize=(20,5))
sns.countplot(hr_dat['Age'],hue=hr_dat['Attrition'])
plt.title('Age and Attrition')
plt.show()

# %% [markdown]
# The above plot shows that the minimum age is 18 and maximum age is 60 in this data.
#
# This plot shows that younger employees have higher chances of leaving a company than employees above the age of 35.
#
# Also, the chances of leaving a company is highest between the age of 25-35. This maybe because after gaining good experience in a company for 5-10 years, employees may tend towards changing a company in search of higher compensations and also there can be many other factors.
#
# The employees from the age group of 18-20 can be seen leaving more than staying, maybe because at such age most of the people are doing internships which are temporary.
#
# But after seeing above plot, we can say that, it is more likely for an employee to stay than to leave a firm, regardless of Age.

# %%
#plotting business travel v/s attrition
plt.figure(figsize=(20,5))
sns.countplot(hr_dat['BusinessTravel'],hue=hr_dat['Attrition'])
plt.title('Business Travel and Attrition')
plt.show()

# %% [markdown]
# Maximum number of employees in this dataset rarely have to do business related travels.
#
# 300-400 employees in this dataset travel frequently for business.
#
# about 200 people in this dataset never had to travel for business.
#
# After seeing above plot, we can say that, it is more likely for an employee to stay than to leave a firm,regardless of BusinessTravel.

# %%
#plotting department wise attrition
plt.figure(figsize=(20,5))
sns.countplot(hr_dat['Department'],hue=hr_dat['Attrition'])
plt.title('department wise attrition')
plt.show()

# %% [markdown]
# Maximum employees are from research and development department, about 500 employees are from sales department, about 100 employees are from HR department.
#
# After seeing above plot, we can say that, it is more likely for an employee to stay than to leave a firm,regardless of Department.

# %%
#Plotting the relation of attrition with distance from home
plt.figure(figsize=(20,5))
sns.countplot(hr_dat['DistanceFromHome'],hue=hr_dat['Attrition'])
plt.title('relation of attrition with distance from home')
plt.show()

# %% [markdown]
# Maximum number of employees live near their office.
#
# After seeing above plot, we can say that, it is more likely for an employee to stay than to leave a firm, regardless of distance from home .

# %%
#plotting relation of education with attrition
plt.figure(figsize=(20,5))
sns.countplot(hr_dat['Education'],hue=hr_dat['Attrition'])
plt.title('relation of education with attrition')
plt.show()

# %% [markdown]
# Most of the employees have an education level of 3.
#
# After seeing above plot, we can say that, it is more likely for an employee to stay than to leave a firm, regardless of education level.

# %%
#plotting relation of EnvironmentSatisfaction with attrition
plt.figure(figsize=(20,5))
sns.countplot(hr_dat['EnvironmentSatisfaction'],hue=hr_dat['Attrition'])
plt.title('relation of EnvironmentSatisfaction with attrition')
plt.show()

# %% [markdown]
# Maximum employees have good satisfaction of there work environment.
#
# We can see that people who are less satisfied with their job environments have relatively more chances of leaving a firm.
#
# After seeing above plot, we can say that, it is more likely for an employee to stay than to leave a firm, regardless of Environment satisfaction.

# %%
#plotting relation of gender with attrition
plt.figure(figsize=(20,5))
sns.countplot(hr_dat['Gender'],hue=hr_dat['Attrition'])
plt.title('relation of Gender with attrition')
plt.show()

# %% [markdown]
# There are more male employees than female employees.
#
# Out of almost 600 female employees, almost 100 left, i.e 16.7% left.
#
# Out of almost 850 male employees, almost 150 left, i.e 17.6% left.
#
# In relative terms, Male employees have more chance of leaving a firm than Female employees.

# %%
#plotting relation of JobSatisfaction with attrition
plt.figure(figsize=(20,5))
sns.countplot(hr_dat['JobSatisfaction'],hue=hr_dat['Attrition'])
plt.title('relation of JobSatisfaction with attrition')
plt.show()

# %% [markdown]
# Maximum emplyees are satisfied with their jobs.
#
# We can see that people who are less satisfied with their jobs have relatively more chances of leaving a firm.

# %%
#plotting relation of MaritalStatus with attrition
plt.figure(figsize=(20,5))
sns.countplot(hr_dat['MaritalStatus'],hue=hr_dat['Attrition'])
plt.title('relation of MaritalStatus with attrition')
plt.show()

# %% [markdown]
# Most of the employees are married.
#
# Single employees are relatively more likely to leave than married or divorced.

# %%
#plotting relation of OverTime with attrition
plt.figure(figsize=(20,5))
sns.countplot(hr_dat['OverTime'],hue=hr_dat['Attrition'])
plt.title('relation of OverTime with attrition')
plt.show()

# %% [markdown]
# Most of the employees don't do OverTime.
#
# Employees who do Overtime are relatively more likely to leave than the employees who don't do overtime.

# %%
#plotting relation of StockOptionLevel with attrition
plt.figure(figsize=(20,5))
sns.countplot(hr_dat['StockOptionLevel'],hue=hr_dat['Attrition'])
plt.title('relation of StockOptionLevel with attrition')
plt.show()

# %% [markdown]
# Employees with no stock options(0) are relatively more likely to leave than the employees with stock options.

# %%
#plotting relation of TotalWorkingYears with attrition
plt.figure(figsize=(20,5))
sns.countplot(hr_dat['TotalWorkingYears'],hue=hr_dat['Attrition'])
plt.title('relation of TotalWorkingYears with attrition')
plt.show()

# %% [markdown]
# Maximum employees have 10 years of experience.
#
# Employees with 1 year of experience or Freshers are more likely to leave a company.

# %%
#plotting relation of TrainingTimesLastYear with attrition
plt.figure(figsize=(20,5))
sns.countplot(hr_dat['TrainingTimesLastYear'],hue=hr_dat['Attrition'])
plt.title('relation of TrainingTimesLastYear with attrition')
plt.show()

# %% [markdown]
# Most of the employees were trained 2-3 times in last year.
#
# Employees who were not trained at all last year are relatively more likely to leave .

# %%
#plotting relation of WorkLifeBalance with attrition
plt.figure(figsize=(20,5))
sns.countplot(hr_dat['WorkLifeBalance'],hue=hr_dat['Attrition'])
plt.title('relation of WorkLifeBalance with attrition')
plt.show()

# %% [markdown]
# Employees with poor work life balance(1), are relatively more likely to leave.

# %%
#plotting relation of YearsAtCompany with attrition
plt.figure(figsize=(20,5))
sns.countplot(hr_dat['YearsAtCompany'],hue=hr_dat['Attrition'])
plt.title('relation of YearsAtCompany with attrition')
plt.show()

# %% [markdown]
# There are employees who have worked for almost 40 years. After that they obviously may have retired.
#
# The employees who have worked for 1 year or less at a company are relatively more likely to leave.

# %%
#plotting relation of YearsWithCurrManager with attrition
plt.figure(figsize=(20,5))
sns.countplot(hr_dat['YearsWithCurrManager'],hue=hr_dat['Attrition'])
plt.title('relation of YearsWithCurrManager with attrition')
plt.show()

# %% [markdown]
# Empolyees who are new to current manager are relatively more likely to leave.

# %%
#plotting the relationship of monthly income with attrition
plt.figure(figsize=(20,5))
sns.barplot(x=hr_dat['Attrition'],y=hr_dat['MonthlyIncome'])
plt.title('relationship of monthly income with attrition')
plt.show()

# %% [markdown]
# Employees with relatively less monthly income are more likely to leave.

# %%
#visualising columns
hr_dat.hist(grid=True,bins=20,layout=(7,5),figsize=(20,20))
plt.show()

# %% [markdown]
# Some of the columns are right skewed.None of the columns are left skewed.

# %%
#check skewness of data
hr_dat.skew()
# Out:
# Age                         0.413286
# DailyRate                  -0.003519
# DistanceFromHome            0.958118
# Education                  -0.289681
# EnvironmentSatisfaction    -0.321654
# HourlyRate                 -0.032311
# JobInvolvement             -0.498419
# JobLevel                    1.025401
# JobSatisfaction            -0.329672
# MonthlyIncome               1.369817
# MonthlyRate                 0.018578
# NumCompaniesWorked          1.026471
# PercentSalaryHike           0.821128
# PerformanceRating           1.921883
# RelationshipSatisfaction   -0.302828
# StockOptionLevel            0.968980
# TotalWorkingYears           1.117172
# TrainingTimesLastYear       0.553124
# WorkLifeBalance            -0.552480
# YearsAtCompany              1.764529
# YearsInCurrentRole          0.917363
# YearsSinceLastPromotion     1.984290
# YearsWithCurrManager        0.833451
# dtype: float64

# %% [markdown]
# The skewness of all the continuous variables need to be improved.Rest all are discrete variables,we won't improve there skewness. Also all continuous variables are positively skewed.

# %% [markdown]
# Let us remove skewness where columns have skewness corfficient of more than 0.5

# %%
#remove skewness of columns with skewness coeff more than 0.5 using log
for i in hr_dat.columns:
    if hr_dat[i].dtype=='int64':
        if hr_dat[i].skew() > 0.5:
            hr_dat[i]=np.log1p(hr_dat[i])
        if hr_dat[i].skew() < -0.5:
            hr_dat[i]=np.square(hr_dat[i])

# %%
#check the improved skewness 
hr_dat.skew()
# Out:
# Age                         0.413286
# DailyRate                  -0.003519
# DistanceFromHome           -0.029121
# Education                  -0.289681
# EnvironmentSatisfaction    -0.321654
# HourlyRate                 -0.032311
# JobInvolvement             -0.498419
# JobLevel                    0.448133
# JobSatisfaction            -0.329672
# MonthlyIncome               0.286448
# MonthlyRate                 0.018578
# NumCompaniesWorked          0.092896
# PercentSalaryHike           0.513543
# PerformanceRating           1.921883
# RelationshipSatisfaction   -0.302828
# StockOptionLevel            0.271963
# TotalWorkingYears           0.322355
# TrainingTimesLastYear       0.492375
# WorkLifeBalance             0.301318
# YearsAtCompany             -0.207708
# YearsInCurrentRole         -0.383498
# YearsSinceLastPromotion     0.718805
# YearsWithCurrManager       -0.357686
# dtype: float64

# %% [markdown]
# The skewness of all the continuous variables is improved.

# %%
#encode target varible (attrition)
#import label encoder from sklearn
import sklearn
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
hr_dat['Attrition']=le.fit_transform(hr_dat['Attrition'])

# %%
#plotting correlation heatmap
plt.figure(figsize=(20,10))
sns.heatmap(hr_dat.corr(),annot=True)
plt.show()

# %% [markdown]
# To avoid multi-colinearity, let us drop one feature from all the feature pairs which are highly correlated(more than 0.7) with each other :
#
# We have high correlation between features joblevel and monthly income,but the magnitude of correlation of joblevel with the target variable(attrition) is less than that of monthly income. So let's drop the feature job level.
#
# In similar way we can remove the features 'performance rating','years in current role','years with current manager'.

# %%
#dropping the above mentioned features
hr_dat.drop(['JobLevel','PerformanceRating','YearsInCurrentRole','YearsWithCurrManager'],axis=1,inplace=True)

# %%
#seperating target varibale
x=hr_dat.drop('Attrition',axis=1)
y=hr_dat['Attrition']

# %%
#check object features in x
for o in x.columns:
    if x[o].dtype=='object':
        print(o)
# Out:
# BusinessTravel
# Department
# EducationField
# Gender
# JobRole
# MaritalStatus
# OverTime

# %%
#encode all the categorical varibles in x
x=pd.get_dummies(x)
x.head()
# Out:
#    Age  DailyRate  DistanceFromHome  Education  EnvironmentSatisfaction  \
# 0   41       1102          0.693147          2                        2
# 1   49        279          2.197225          1                        3
# 2   37       1373          1.098612          2                        4
# 3   33       1392          1.386294          4                        4
# 4   27        591          1.098612          1                        1
#
#    HourlyRate  JobInvolvement  JobSatisfaction  MonthlyIncome  MonthlyRate  \
# 0          94               3                4       8.698514        19479
# 1          61               2                2       8.543056        24907
# 2          92               2                3       7.645398         2396
# 3          56               3                3       7.975908        23159
# 4          40               3                2       8.151622        16632
#
#    ...  JobRole_Manufacturing Director  JobRole_Research Director  \
# ...

# %%
#visualising features
x.plot(kind='box',subplots=True,layout=(7,7),figsize=(20,20))
plt.show()

# %% [markdown]
# We see few columns with outliers.

# %% [markdown]
# But they are not significant , so we will ignore them.

# %%
#scaling the input variables
from sklearn.preprocessing import StandardScaler
scale=StandardScaler()
x=pd.DataFrame(scale.fit_transform(x),columns=x.columns)
x.head()
# Out:
#         Age  DailyRate  DistanceFromHome  Education  EnvironmentSatisfaction  \
# 0  0.446350   0.742527         -1.505350  -0.891688                -0.660531
# 1  1.322365  -1.297775          0.252002  -1.868426                 0.254625
# 2  0.008343   1.414363         -1.031607  -0.891688                 1.169781
# 3 -0.429664   1.461466         -0.695482   1.061787                 1.169781
# 4 -1.086676  -0.524295         -1.031607  -1.868426                -1.575686
#
#    HourlyRate  JobInvolvement  JobSatisfaction  MonthlyIncome  MonthlyRate  \
# 0    1.383138        0.379672         1.153254       0.219493     0.726020
# 1   -0.240677       -1.026167        -0.660853      -0.014600     1.488876
# 2    1.284725       -1.026167         0.246200      -1.366318    -1.674841
# 3   -0.486709        0.379672         0.246200      -0.868626     1.243211
# 4   -1.274014        0.379672        -0.660853      -0.604032     0.325900
#
# ...

# %% [markdown]
# # TRAINING AND TESTING THE MODEL

# %%
#train-test-split
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=4)

# %%
#importing all the base classification algorithms
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier

# %%
#importing all the metrics for regression analysis
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix,roc_curve,roc_auc_score

# %%
#selecting the base algorithm which works best 
from sklearn.model_selection import cross_val_score
model_list=[LogisticRegression(),KNeighborsClassifier(),GaussianNB(),SVC(),DecisionTreeClassifier()]
for model in model_list:
    results=cross_val_score(model,x_train,y_train,cv=10,scoring='accuracy')
    print(model)
    print('mean score : ',results.mean())
    print('\n')
# Out:
# LogisticRegression()
# mean score :  0.8741561639866726
#
#
# KNeighborsClassifier()
# mean score :  0.8469288715051426
#
#
# GaussianNB()
# mean score :  0.7372229465449804
#
#
# SVC()
# mean score :  0.8605461393596988
#
#
# DecisionTreeClassifier()
# mean score :  0.792539475590323

# %% [markdown]
# LogisticRegression and SVC are giving better generalised scores.

# %% [markdown]
# # 1) SVC

# %%
#tuning hyperparameters of svc
from sklearn.model_selection import GridSearchCV
svc=SVC()
params = {
 'C' : [0.001,0.01,0.1,1,10,100],
 'kernel':['linear','poly','rbf']
 }
GCV_svc=GridSearchCV(estimator=svc,param_grid=params,cv=10)
GCV_svc.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=10, estimator=SVC(),
#              param_grid={'C': [0.001, 0.01, 0.1, 1, 10, 100],
#                          'kernel': ['linear', 'poly', 'rbf']})

# %%
#getting best parameters for svc
print('best parameters :',GCV_svc.best_params_)
# Out:
# best parameters : {'C': 0.1, 'kernel': 'linear'}

# %%
#training and testing with best parameters of svc
svc_best=SVC(C= 0.1, kernel= 'linear',probability=True)
svc_best.fit(x_train,y_train)
prediction=svc_best.predict(x_test)
print('accuracy_score :',accuracy_score(y_test,prediction))
print('confusion matrix :','\n',confusion_matrix(y_test,prediction))
print('classification report :','\n',classification_report(y_test,prediction))
print('roc_auc_score : ',roc_auc_score(y_test,prediction))
# Out:
# accuracy_score : 0.9115646258503401
# confusion matrix :
#  [[247   4]
#  [ 22  21]]
# classification report :
#                precision    recall  f1-score   support
#
#            0       0.92      0.98      0.95       251
#            1       0.84      0.49      0.62        43
#
#     accuracy                           0.91       294
#    macro avg       0.88      0.74      0.78       294
# weighted avg       0.91      0.91      0.90       294
#
# roc_auc_score :  0.7362179190215881

# %%
#generalised accuracy score using best parameters of svc
cv_scores=cross_val_score(svc_best,x_train,y_train,cv=10,scoring='accuracy')
print('mean accuracy score :',cv_scores.mean())
# Out:
# mean accuracy score : 0.8784224250325945

# %%
#generalised roc_auc score using best parameters of AdaBoost with LogisticRegressor as base estimator
cv_scores=cross_val_score(svc_best,x_train,y_train,cv=10,scoring='roc_auc')
print('mean roc_auc score :',cv_scores.mean())
# Out:
# mean roc_auc score : 0.8267931462856275

# %%
#plotting roc_curve of LogisticRegression .
pred_pro=svc_best.predict_proba(x_test)[:,1]
fpr,tpr,threshholds=roc_curve(y_test,pred_pro,pos_label=True)
plt.plot(fpr,tpr)
plt.xlabel('false positive rate')
plt.ylabel('true positive rate')
plt.title('roc_curve')
plt.show()

# %% [markdown]
# # 2) LogisticRegression

# %%
#tuning hyperparameters of LogisticRegressor
lr=LogisticRegression()
param = {
 'penalty': ['l1','l2'],
 'C' : [0.001,0.01,0.1,1,10,100,1000],
 'solver':['newton-cg','lbfgs','liblinear','sag','saga']
 }
GCV_lr=GridSearchCV(estimator=lr,param_grid=param,cv=10)
GCV_lr.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=10, estimator=LogisticRegression(),
#              param_grid={'C': [0.001, 0.01, 0.1, 1, 10, 100, 1000],
#                          'penalty': ['l1', 'l2'],
#                          'solver': ['newton-cg', 'lbfgs', 'liblinear', 'sag',
#                                     'saga']})

# %%
#getting best parameters for LogisticRegressor
print('best parameters :',GCV_lr.best_params_)
# Out:
# best parameters : {'C': 0.1, 'penalty': 'l2', 'solver': 'newton-cg'}

# %%
#training and testing with best parameters of LogisticRegressor
lr_best=LogisticRegression(C= 0.1, penalty= 'l2', solver= 'newton-cg')
lr_best.fit(x_train,y_train)
predictions=lr_best.predict(x_test)
print('accuracy_score :',accuracy_score(y_test,predictions))
print('confusion matrix :','\n',confusion_matrix(y_test,predictions))
print('classification report :','\n',classification_report(y_test,predictions))
print('roc_auc_score : ',roc_auc_score(y_test,predictions))
# Out:
# accuracy_score : 0.9081632653061225
# confusion matrix :
#  [[248   3]
#  [ 24  19]]
# classification report :
#                precision    recall  f1-score   support
#
#            0       0.91      0.99      0.95       251
#            1       0.86      0.44      0.58        43
#
#     accuracy                           0.91       294
#    macro avg       0.89      0.71      0.77       294
# weighted avg       0.90      0.91      0.90       294
#
# roc_auc_score :  0.7149541369406096

# %%
#generalised accuracy score using best parameters of LogisticRegressor
cv_scores=cross_val_score(lr_best,x_train,y_train,cv=10,scoring='accuracy')
print('mean accuracy score :',cv_scores.mean())
# Out:
# mean accuracy score : 0.8775677241778939

# %%
#generalised roc_auc score using best parameters of AdaBoost with LogisticRegressor as base estimator
cv_scores=cross_val_score(lr_best,x_train,y_train,cv=10,scoring='roc_auc')
print('mean roc_auc score :',cv_scores.mean())
# Out:
# mean roc_auc score : 0.8297699606158252

# %%
#plotting roc_curve of LogisticRegression .
pred_prob=lr_best.predict_proba(x_test)[:,1]
fpr,tpr,threshholds=roc_curve(y_test,pred_prob,pos_label=True)
plt.plot(fpr,tpr)
plt.xlabel('false positive rate')
plt.ylabel('true positive rate')
plt.title('roc_curve')
plt.show()

# %% [markdown]
# # Final Selection betweeen LogisticRegression and SVC

# %% [markdown]
# After analysing both the algorithms we came to a conclusion that both these algorithm are working almost equally. So, we can go ahead with any of these two algorithms for final training.
#
# Selecting LogisticRegression as Final base model.(As mean roc_auc score is slightly better than that of SVC).

# %% [markdown]
# let us try to improve the model performance by boosting algorithm.

# %%
#boosting the algorithm using AdaBoost and tuning it.
from sklearn.ensemble import AdaBoostClassifier
ada_lr=AdaBoostClassifier(base_estimator=lr_best)
para = {
 'n_estimators': [50, 100,150,200,250,300],
 'algorithm':['SAMME','SAMME.R']
 }
GCV_ada_lr=GridSearchCV(estimator=ada_lr,param_grid=para,cv=10)
GCV_ada_lr.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=10,
#              estimator=AdaBoostClassifier(base_estimator=LogisticRegression(C=0.1,
#                                                                             solver='newton-cg')),
#              param_grid={'algorithm': ['SAMME', 'SAMME.R'],
#                          'n_estimators': [50, 100, 150, 200, 250, 300]})

# %%
#getting best parameters of AdaBoost 
print('best parameters :',GCV_ada_lr.best_params_)
# Out:
# best parameters : {'algorithm': 'SAMME.R', 'n_estimators': 50}

# %%
#training and testing with best parameters of AdaBoostClassifier
ada_lr_best=AdaBoostClassifier(base_estimator=lr_best,algorithm='SAMME.R',n_estimators=50)
ada_lr_best.fit(x_train,y_train)
preds=ada_lr_best.predict(x_test)
print('accuracy_score :',accuracy_score(y_test,preds))
print('confusion matrix :','\n',confusion_matrix(y_test,preds))
print('classification report :','\n',classification_report(y_test,preds))
print('roc_auc_score :',roc_auc_score(y_test,preds))
# Out:
# accuracy_score : 0.9013605442176871
# confusion matrix :
#  [[251   0]
#  [ 29  14]]
# classification report :
#                precision    recall  f1-score   support
#
#            0       0.90      1.00      0.95       251
#            1       1.00      0.33      0.49        43
#
#     accuracy                           0.90       294
#    macro avg       0.95      0.66      0.72       294
# weighted avg       0.91      0.90      0.88       294
#
# roc_auc_score : 0.6627906976744187

# %% [markdown]
# Looking at the curve , we can say that the model is performing good!

# %%
#generalised accuracy score using best parameters of AdaBoost with LogisticRegressor as base estimator
cv_scores=cross_val_score(ada_lr_best,x_train,y_train,cv=10,scoring='accuracy')
print('mean accuracy score :',cv_scores.mean())
# Out:
# mean accuracy score : 0.8656671012603218

# %%
#generalised roc_auc score using best parameters of AdaBoost with LogisticRegressor as base estimator
cv_scores=cross_val_score(ada_lr_best,x_train,y_train,cv=10,scoring='roc_auc')
print('mean roc_auc score :',cv_scores.mean())
# Out:
# mean roc_auc score : 0.8223691534029879

# %% [markdown]
# After using Adaboost the mean accuracy and roc_auc scores are decresed by small amount.It is better we only use LogisticRegression for final fitting.

# %%
#finally fitting 100% data for deployment
lr_best.fit(x,y)
lr_best.score(x,y)
# Out:
# 0.8931972789115646

# %%
#saving the model using joblib
import joblib 
joblib.dump(lr_best,'hr_analytics.pkl')
# Out:
# ['hr_analytics.pkl']
